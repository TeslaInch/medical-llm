# %%
# !pip install -q transformers peft trl bitsandbytes accelerate datasets wandb huggingface_hub
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.1/825.1 kB 12.6 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 31.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 94.2 MB/s eta 0:00:00:00:010:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# ...

# %%
# !pip install -q groq
import os
os.environ["GROQ_API_KEY"] = "your groq api key here"

# %%
from huggingface_hub import login
import wandb

# paste your keys directly here for now
os.environ["HF_TOKEN"] = "your key here"
os.environ["WANDB_API_KEY"] = "your key here"

login(token=os.environ["HF_TOKEN"])
wandb.login(key=os.environ["WANDB_API_KEY"])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: WARNING [wandb.login()] Changing session credentials to explicit value for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import PeftModel

BASE_MODEL = "microsoft/Phi-3.5-mini-instruct"
ADAPTER = "TeslaInch/scd-phi35-adapter"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_use_double_quant=True,
)

# load base model
print("Loading base model...")
model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=bnb_config,
    device_map="auto",
    dtype=torch.bfloat16,
    attn_implementation="eager",
)

# load your adapter on top
print("Loading SCD adapter...")
model = PeftModel.from_pretrained(model, ADAPTER)
model.eval()

# load tokenizer
tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

print(f"Ready")
print(f"GPU memory: {torch.cuda.memory_allocated()/1e9:.2f} GB")
# Out:
# Loading base model...
# config.json: 0.00B [00:00, ?B/s]
# This model config has set a `rope_parameters['original_max_position_embeddings']` field, to be used together with `max_position_embeddings` to determine a scaling factor. Please set the `factor` field of `rope_parameters`with this ratio instead -- we recommend the use of this field over `original_max_position_embeddings`, as it is compatible with most model architectures.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# ...
# Loading weights:   0%|          | 0/195 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/195 [00:00<?, ?B/s]
# Loading SCD adapter...
# adapter_config.json: 0.00B [00:00, ?B/s]
# ...

# %%
import os

for root, dirs, files in os.walk('/kaggle/input'):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /kaggle/input/datasets/teslaincarnate/jsonfiles/all_questions.json
# /kaggle/input/datasets/teslaincarnate/jsonfiles/all_answers.json

# %%
import json

with open("/kaggle/input/datasets/teslaincarnate/jsonfiles/all_questions.json") as f:
    questions = json.load(f)

with open("/kaggle/input/datasets/teslaincarnate/jsonfiles/all_answers.json") as f:
    answers = json.load(f)

print(f"Total questions: {len(questions)}")
print(f"Total answers: {len(answers)}")

print(f"\nFirst question entry:")
print(json.dumps(questions[0], indent=2))

print(f"\nFirst answer entry:")
print(json.dumps(answers[0], indent=2))

print(f"\nLast question entry:")
print(json.dumps(questions[-1], indent=2))
# Out:
# Total questions: 584
# Total answers: 584
#
# First question entry:
# {
#   "index": 1,
#   "id": "layer1_001",
#   "layer": 1,
#   "source": "Custom SCD Notes",
#   "category": "pathophysiology",
#   "question": "What specific genetic mutation causes sickle cell disease?"
# }
#
# First answer entry:
# {
#   "index": 1,
#   "id": "layer1_001",
#   "layer": 1,
#   "source": "Custom SCD Notes",
#   "category": "pathophysiology",
#   "answer": "A single point mutation in codon 6 of the HBB gene on chromosome 11, replacing glutamic acid with valine (Glu6Val). This causes production of HbS instead of normal HbA, and HbS polymerizes when deoxygenated, distorting red blood cells into the sickle shape.",
#   "rubric": null
# }
#
# Last question entry:
# {
#   "index": 584,
#   "id": "layer5_008",
#   "layer": 5,
#   "source": "ASH 2019 SCD Guidelines: Cardiopulmonary & Kidney Disease (reaffirmed, 2025 CPKD update report)",
#   "category": "treatment_threshold",
# ...

# %%
import json
import torch
from transformers import pipeline
from groq import Groq
import time
import os

# ── load files ────────────────────────────────────────────────────────────────
with open("/kaggle/input/datasets/teslaincarnate/jsonfiles/all_questions.json") as f:
    questions = json.load(f)

with open("/kaggle/input/datasets/teslaincarnate/jsonfiles/all_answers.json") as f:
    answers = json.load(f)

# index answers by id for fast lookup
answer_map = {a["id"]: a for a in answers}

print(f"Questions: {len(questions)}")
print(f"Answers: {len(answers)}")

# ── layer 4 case lookup ───────────────────────────────────────────────────────
# load layer4 file to get case field
# upload your layer4_clinical_cases.json to kaggle input too
# if not available, layer4 questions will use question field only
try:
    with open("/kaggle/input/datasets/teslaincarnate/jsonfiles/layer4_clinical_cases.json") as f:
        layer4_raw = json.load(f)
    case_map = {q["id"]: q.get("case", "") for q in layer4_raw}
    print(f"Layer 4 cases loaded: {len(case_map)}")
except:
    case_map = {}
    print("Layer 4 case file not found — using question field only")

# ── inference pipeline ────────────────────────────────────────────────────────
print("\nSetting up inference pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=400,
    do_sample=False,
    pad_token_id=tokenizer.eos_token_id,
)

SYSTEM = (
    "You are a medical AI assistant specialised in sickle cell disease. "
    "Answer the following clinical question accurately and completely."
)

def build_prompt(q):
    case = case_map.get(q["id"], "")
    if case:
        user_content = f"{SYSTEM}\nClinical case:\n{case}\n\nQuestion: {q['question']}"
    else:
        user_content = f"{SYSTEM}\n{q['question']}"
    return f"<|user|>\n{user_content}<|end|>\n<|assistant|>\n"

def get_response(q):
    prompt = build_prompt(q)
    output = pipe(prompt)
    full_text = output[0]["generated_text"]
    # extract only what comes after <|assistant|>
    response = full_text.split("<|assistant|>")[-1].strip()
    # remove trailing end token if present
    response = response.replace("<|end|>", "").strip()
    return response

# ── groq judge ────────────────────────────────────────────────────────────────
groq_client = Groq(api_key=os.environ["GROQ_API_KEY"])

LAYER_RUBRICS = {
    1: "Score 0-2. 2=correct answer with sound reasoning. 1=partially correct or incomplete. 0=wrong or dangerous.",
    2: "Score 0-1. 1=correct answer. 0=wrong answer.",
    3: "Score 0-2. 2=correct, matches guideline. 1=partially correct. 0=wrong or contradicts guideline.",
    4: "Score 0-3. 3=correct diagnosis and full management in priority order. 2=correct diagnosis, partial management. 1=partial diagnosis or incomplete management. 0=wrong or dangerous.",
    5: "Score 0-2. 2=correct, matches ASH guideline. 1=partially correct. 0=wrong or contradicts guideline.",
}

MAX_SCORES = {1: 2, 2: 1, 3: 2, 4: 3, 5: 2}

def judge(question_text, gold_answer, model_response, layer, case=""):
    full_q = f"Clinical case:\n{case}\n\nQuestion: {question_text}" if case else question_text
    rubric = LAYER_RUBRICS.get(layer, LAYER_RUBRICS[1])

    prompt = f"""You are a clinical expert evaluating a medical AI response on sickle cell disease.

QUESTION: {full_q}

GOLD STANDARD ANSWER: {gold_answer}

MODEL RESPONSE: {model_response}

RUBRIC: {rubric}

Respond in this exact JSON format with no other text:
{{"score": <int>, "reasoning": "<one sentence>"}}"""

    for attempt in range(5):
        try:
            response = groq_client.chat.completions.create(
                model="llama-3.1-8b-instant",
                messages=[{"role": "user", "content": prompt}],
                temperature=0,
            )
            text = response.choices[0].message.content.strip()
            if "```" in text:
                text = text.split("```")[1]
                if text.startswith("json"):
                    text = text[4:]
            parsed = json.loads(text.strip())
            return {
                "score": int(parsed["score"]),
                "judge_reasoning": parsed["reasoning"],
                "judge_error": False
            }
        except Exception as e:
            if "429" in str(e) or "rate" in str(e).lower():
                wait = (2 ** attempt) * 3
                print(f"  Rate limited. Waiting {wait}s...")
                time.sleep(wait)
            else:
                return {
                    "score": None,
                    "judge_reasoning": f"Error: {str(e)}",
                    "judge_error": True
                }

    return {"score": None, "judge_reasoning": "Max retries exceeded", "judge_error": True}

# ── main eval loop ────────────────────────────────────────────────────────────
print("\nStarting evaluation...")
print("This will take a while — checkpoint saved every 50 questions\n")

results = []
OUTPUT_PATH = "/kaggle/working/finetuned_eval_results.json"

for i, q in enumerate(questions):
    qid = q["id"]
    layer = q["layer"]

    # get gold answer
    if qid not in answer_map:
        print(f"  [{i+1}] {qid} — no answer found, skipping")
        continue

    gold = answer_map[qid]["answer"]
    case = case_map.get(qid, "")

    # get model response
    print(f"[{i+1}/{len(questions)}] {qid}...", end=" ", flush=True)
    try:
        response = get_response(q)
    except Exception as e:
        print(f"inference error: {e}")
        continue

    # judge the response
    judgment = judge(q["question"], gold, response, layer, case)
    max_score = MAX_SCORES.get(layer, 2)

    result = {
        "id": qid,
        "layer": layer,
        "category": q.get("category", ""),
        "source": q.get("source", ""),
        "question": q["question"],
        "gold_answer": gold,
        "model_response": response,
        "score": judgment["score"],
        "max_score": max_score,
        "pct_score": round(judgment["score"] / max_score * 100, 1) if judgment["score"] is not None else None,
        "judge_reasoning": judgment["judge_reasoning"],
        "judge_error": judgment["judge_error"],
        "model": "scd-phi35-finetuned-v1"
    }
    results.append(result)

    score_str = f"{judgment['score']}/{max_score}" if judgment["score"] is not None else "error"
    print(f"score: {score_str}")

    # rate limit buffer
    time.sleep(2)

    # checkpoint every 50
    if (i + 1) % 50 == 0:
        with open(OUTPUT_PATH, "w") as f:
            json.dump(results, f, indent=2)
        print(f"\n  [checkpoint saved — {i+1}/{len(questions)} done]\n")

# final save
with open(OUTPUT_PATH, "w") as f:
    json.dump(results, f, indent=2)

print(f"\nDone. Results saved to {OUTPUT_PATH}")

# ── summary ───────────────────────────────────────────────────────────────────
scored = [r for r in results if r["score"] is not None]
pct_scores = [r["score"] / r["max_score"] for r in scored]
overall = sum(pct_scores) / len(pct_scores) * 100

print(f"\n{'='*50}")
print(f"FINE-TUNED MODEL EVAL RESULTS")
print(f"{'='*50}")
print(f"Scored:  {len(scored)}/{len(results)}")
print(f"Overall: {overall:.1f}%")

print(f"\nBy layer:")
for layer in sorted(set(r["layer"] for r in scored)):
    lr = [r for r in scored if r["layer"] == layer]
    lpct = sum(r["score"]/r["max_score"] for r in lr) / len(lr) * 100
    print(f"  Layer {layer}: {lpct:.1f}%  ({len(lr)} questions)")

print(f"\nBy category:")
cats = sorted(set(r["category"] for r in scored if r["category"]))
for cat in cats:
    cr = [r for r in scored if r["category"] == cat]
    cpct = sum(r["score"]/r["max_score"] for r in cr) / len(cr) * 100
    print(f"  {cat:<35} {cpct:.1f}%  ({len(cr)} questions)")

# %%
import json
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, pipeline
from peft import PeftModel
from groq import Groq
import time
import os

# ── clear adapter model from memory ──────────────────────────────────────────
print("Clearing adapter model from memory...")
del model
torch.cuda.empty_cache()
print(f"GPU memory after clear: {torch.cuda.memory_allocated()/1e9:.2f} GB")

# ── load BASE model only — no adapter ────────────────────────────────────────
BASE_MODEL = "microsoft/Phi-3.5-mini-instruct"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_use_double_quant=True,
)

print("Loading Phi-3.5 Mini BASE model (no adapter)...")
base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=bnb_config,
    device_map="auto",
    dtype=torch.bfloat16,
    attn_implementation="eager",
)
base_model.eval()

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

print(f"Base model loaded — no adapter")
print(f"GPU memory: {torch.cuda.memory_allocated()/1e9:.2f} GB")

# ── load files ────────────────────────────────────────────────────────────────
with open("/kaggle/input/datasets/teslaincarnate/jsonfiles/all_questions.json") as f:
    questions = json.load(f)

with open("/kaggle/input/datasets/teslaincarnate/jsonfiles/all_answers.json") as f:
    answers = json.load(f)

answer_map = {a["id"]: a for a in answers}

try:
    with open("/kaggle/input/datasets/teslaincarnate/jsonfiles/layer4_clinical_cases.json") as f:
        layer4_raw = json.load(f)
    case_map = {q["id"]: q.get("case", "") for q in layer4_raw}
    print(f"Layer 4 cases loaded: {len(case_map)}")
except:
    case_map = {}
    print("Layer 4 case file not found — using question field only")

print(f"Questions: {len(questions)}")
print(f"Answers: {len(answers)}")

# ── inference pipeline ────────────────────────────────────────────────────────
print("\nSetting up inference pipeline...")
pipe = pipeline(
    "text-generation",
    model=base_model,
    tokenizer=tokenizer,
    max_new_tokens=400,
    do_sample=False,
    pad_token_id=tokenizer.eos_token_id,
)

SYSTEM = (
    "You are a medical AI assistant specialised in sickle cell disease. "
    "Answer the following clinical question accurately and completely."
)

def build_prompt(q):
    case = case_map.get(q["id"], "")
    if case:
        user_content = f"{SYSTEM}\nClinical case:\n{case}\n\nQuestion: {q['question']}"
    else:
        user_content = f"{SYSTEM}\n{q['question']}"
    return f"<|user|>\n{user_content}<|end|>\n<|assistant|>\n"

def get_response(q):
    prompt = build_prompt(q)
    output = pipe(prompt)
    full_text = output[0]["generated_text"]
    response = full_text.split("<|assistant|>")[-1].strip()
    response = response.replace("<|end|>", "").strip()
    return response

# ── groq judge ────────────────────────────────────────────────────────────────
groq_client = Groq(api_key=os.environ["GROQ_API_KEY"])

LAYER_RUBRICS = {
    1: "Score 0-2. 2=correct answer with sound reasoning. 1=partially correct or incomplete. 0=wrong or dangerous.",
    2: "Score 0-1. 1=correct answer. 0=wrong answer.",
    3: "Score 0-2. 2=correct, matches guideline. 1=partially correct. 0=wrong or contradicts guideline.",
    4: "Score 0-3. 3=correct diagnosis and full management in priority order. 2=correct diagnosis, partial management. 1=partial diagnosis or incomplete management. 0=wrong or dangerous.",
    5: "Score 0-2. 2=correct, matches ASH guideline. 1=partially correct. 0=wrong or contradicts guideline.",
}

MAX_SCORES = {1: 2, 2: 1, 3: 2, 4: 3, 5: 2}

def judge(question_text, gold_answer, model_response, layer, case=""):
    full_q = f"Clinical case:\n{case}\n\nQuestion: {question_text}" if case else question_text
    rubric = LAYER_RUBRICS.get(layer, LAYER_RUBRICS[1])

    prompt = f"""You are a clinical expert evaluating a medical AI response on sickle cell disease.

QUESTION: {full_q}

GOLD STANDARD ANSWER: {gold_answer}

MODEL RESPONSE: {model_response}

RUBRIC: {rubric}

Respond in this exact JSON format with no other text:
{{"score": <int>, "reasoning": "<one sentence>"}}"""

    for attempt in range(5):
        try:
            response = groq_client.chat.completions.create(
                model="llama-3.1-8b-instant",
                messages=[{"role": "user", "content": prompt}],
                temperature=0,
            )
            text = response.choices[0].message.content.strip()
            if "```" in text:
                text = text.split("```")[1]
                if text.startswith("json"):
                    text = text[4:]
            parsed = json.loads(text.strip())
            return {
                "score": int(parsed["score"]),
                "judge_reasoning": parsed["reasoning"],
                "judge_error": False
            }
        except Exception as e:
            if "429" in str(e) or "rate" in str(e).lower():
                wait = (2 ** attempt) * 3
                print(f"  Rate limited. Waiting {wait}s...")
                time.sleep(wait)
            else:
                return {
                    "score": None,
                    "judge_reasoning": f"Error: {str(e)}",
                    "judge_error": True
                }

    return {"score": None, "judge_reasoning": "Max retries exceeded", "judge_error": True}

# ── main eval loop ────────────────────────────────────────────────────────────
print("\nStarting BASE MODEL evaluation...")
print("Checkpoint saved every 50 questions\n")

results = []
OUTPUT_PATH = "/kaggle/working/base_model_eval_results.json"

for i, q in enumerate(questions):
    qid = q["id"]
    layer = q["layer"]

    if qid not in answer_map:
        print(f"  [{i+1}] {qid} — no answer found, skipping")
        continue

    gold = answer_map[qid]["answer"]
    case = case_map.get(qid, "")

    print(f"[{i+1}/{len(questions)}] {qid}...", end=" ", flush=True)

    try:
        response = get_response(q)
    except Exception as e:
        print(f"inference error: {e}")
        continue

    judgment = judge(q["question"], gold, response, layer, case)
    max_score = MAX_SCORES.get(layer, 2)

    result = {
        "id": qid,
        "layer": layer,
        "category": q.get("category", ""),
        "source": q.get("source", ""),
        "question": q["question"],
        "gold_answer": gold,
        "model_response": response,
        "score": judgment["score"],
        "max_score": max_score,
        "pct_score": round(judgment["score"] / max_score * 100, 1) if judgment["score"] is not None else None,
        "judge_reasoning": judgment["judge_reasoning"],
        "judge_error": judgment["judge_error"],
        "model": "phi35-mini-base"
    }
    results.append(result)

    score_str = f"{judgment['score']}/{max_score}" if judgment["score"] is not None else "error"
    print(f"score: {score_str}")

    time.sleep(2)

    if (i + 1) % 50 == 0:
        with open(OUTPUT_PATH, "w") as f:
            json.dump(results, f, indent=2)
        print(f"\n  [checkpoint saved — {i+1}/{len(questions)} done]\n")

# ── final save ────────────────────────────────────────────────────────────────
with open(OUTPUT_PATH, "w") as f:
    json.dump(results, f, indent=2)

print(f"\nDone. Results saved to {OUTPUT_PATH}")

# ── summary ───────────────────────────────────────────────────────────────────
scored = [r for r in results if r["score"] is not None]
pct_scores = [r["score"] / r["max_score"] for r in scored]
overall = sum(pct_scores) / len(pct_scores) * 100

print(f"\n{'='*50}")
print(f"BASE MODEL EVAL RESULTS")
print(f"{'='*50}")
print(f"Scored:  {len(scored)}/{len(results)}")
print(f"Overall: {overall:.1f}%")

print(f"\nBy layer:")
for layer in sorted(set(r["layer"] for r in scored)):
    lr = [r for r in scored if r["layer"] == layer]
    lpct = sum(r["score"]/r["max_score"] for r in lr) / len(lr) * 100
    print(f"  Layer {layer}: {lpct:.1f}%  ({len(lr)} questions)")

print(f"\nBy category:")
cats = sorted(set(r["category"] for r in scored if r["category"]))
for cat in cats:
    cr = [r for r in scored if r["category"] == cat]
    cpct = sum(r["score"]/r["max_score"] for r in cr) / len(cr) * 100
    print(f"  {cat:<35} {cpct:.1f}%  ({len(cr)} questions)")
# Out:
# Clearing adapter model from memory...
# GPU memory after clear: 0.85 GB
# Loading Phi-3.5 Mini BASE model (no adapter)...
# Loading weights:   0%|          | 0/195 [00:00<?, ?it/s]
# Base model loaded — no adapter
# GPU memory: 2.22 GB
# Layer 4 case file not found — using question field only
# Questions: 584
# Answers: 584
#
# Setting up inference pipeline...
#
# Starting BASE MODEL evaluation...
# Checkpoint saved every 50 questions
#
# [1/584] layer1_001...
# Both `max_new_tokens` (=400) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# score: 2/2
# [2/584] layer1_002...
# ...
